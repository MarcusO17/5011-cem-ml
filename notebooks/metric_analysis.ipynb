# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/consolidated_data/model_metrics.csv')

# %%
df.drop(df.tail(3).index,inplace=True)

# %%
df_sorted = df.sort_values(by='Mean Square Error')

# %%
plt.figure(figsize=(7,3))
sns.barplot(y=df['Model Name'],x=df['Mean Square Error'],color='red')
plt.title('Model Comparison by Mean Square Error')
plt.legend()
plt.show()
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_22368\123321505.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_sorted = df.sort_values(by='Root Mean Square Error')
df
# Out:
#                  Model Name  Mean Square Error  Root Mean Square Error  \
# 0           Univariate LSTM       7.522007e+05              867.295060
# 1                      LSTM       2.314334e+06             1521.293630
# 2   Multi-Linear Regression       1.501486e+07             1181.448703
# 3                     ARIMA       3.795298e+08            19481.524980
# 4  Random Forest Regression       7.015527e+08             6570.377158
# 5                   Prophet       7.646331e+08            27651.999940
# 6     Exponential Smoothing       1.039858e+09            32246.831340
#
#           R2  Mean Absolute Error
# 0   0.901485           655.448838
# 1   0.696895           822.355397
# 2   0.672992           740.529570
# 3 -20.547017         14616.731450
# 4  -4.391731          5345.319233
# 5 -42.410456         26664.361890
# 6 -58.035786         31829.374600

# %%
df_sorted = df.sort_values(by='Root Mean Square Error')
plt.figure(figsize=(7,3))
sns.barplot(y=df_sorted['Model Name'],x=df_sorted['Root Mean Square Error'],color='orange')
plt.title('Model Comparison by Root Mean Square Error')
plt.legend()
plt.show()
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_22368\151274722.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_sorted = df.sort_values(by='Mean Absolute Error')
plt.figure(figsize=(7,3))
sns.barplot(y=df_sorted['Model Name'],x=df_sorted['Mean Absolute Error'],color='purple')
plt.title('Model Comparison by Mean Absolute Error')
plt.legend()
plt.show()
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_22368\1346933827.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_sorted = df.sort_values(by='R2',ascending=False)
plt.figure(figsize=(7,3))
sns.barplot(y=df_sorted['Model Name'],x=df_sorted['R2'],color='cyan')
plt.title('Model Comparison by R2 Score')
plt.legend()
plt.show()
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_22368\898765184.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
